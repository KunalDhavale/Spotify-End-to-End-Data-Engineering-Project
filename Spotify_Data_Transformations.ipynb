# %% [markdown]
# # <h2><center>Spotify API Data Extract</center></h2>

# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# Enter Your Credentials here

client_credentials_manager = SpotifyClientCredentials(client_id='',
                                                      client_secret='')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'

# %%
playlist_uri = playlist_link.split('/')[-1]
playlist_uri
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
sp.playlist_tracks(playlist_uri)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-05-19T15:28:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#        'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#        'id': '0XeEobZplHxzM9QzFQWLiR',
#        'name': 'Eslabon Armado',
#        'type': 'artist',
#        'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
# ...

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#     'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#     'id': '0XeEobZplHxzM9QzFQWLiR',
#     'name': 'Eslabon Armado',
#     'type': 'artist',
#     'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'ET',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
# ...

# %%
# Album Data

album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_link = row['track']['album']['external_urls']['spotify']
    album_name = row['track']['album']['name']
    rel_date = row['track']['album']['release_date']
    total_tracks = row['track']['album']['total_tracks']
    album = {'album_id':album_id,'album_link':album_link,'album_name':album_name,'rel_date':rel_date,
             'total_tracks':total_tracks}
    album_list.append(album)
album_list
# Out:
# [{'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'album_link': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM',
#   'album_name': 'DESVELADO',
#   'rel_date': '2023-04-28',
#   'total_tracks': 16},
#  {'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'album_link': 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT',
#   'album_name': 'un x100to',
#   'rel_date': '2023-04-17',
#   'total_tracks': 1},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'album_link': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti',
#   'album_name': 'La Bebe (Remix)',
#   'rel_date': '2023-03-17',
#   'total_tracks': 2},
#  {'album_id': '5letLUZIFsQikJYShfGNs4',
#   'album_link': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4',
#   'album_name': 'The Beginning: Cupid',
#   'rel_date': '2023-02-24',
#   'total_tracks': 3},
#  {'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'album_link': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz',
#   'album_name': 'Endless Summer Vacation',
# ...

# %%
# Artist's Data

artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_id = artist['id']
                artist_name = artist['name']
                artist_link = artist['external_urls']['spotify']
                artists = {'artist_id':artist_id, 'artist_name':artist_name, 'artist_link':artist_link}
                artist_list.append(artists)
artist_list
# Out:
# [{'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'artist_link': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'artist_link': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'artist_link': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_link': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'artist_link': 'https://open.spotify.com/artist/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'artist_link': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '4GJ6xDCF5jaUqD6avOuQT6',
# ...

# %%
# Another Way of extracting all the Artists using the Len of the list

artist_list = []    
for j in data['items']:  
    for i in range(len(j['track']['artists'])):    
        artist_id = j['track']['artists'][i]['id']
        artist_name = j['track']['artists'][i]['name']
        artist_link = j['track']['artists'][i]['external_urls']['spotify']
        artist = {'artist_id':artist_id,'artist_name':artist_name,'artist_link':artist_link}
        artist_list.append(artist)
artist_list
# Out:
# [{'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'artist_link': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'artist_link': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'artist_link': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'artist_link': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'artist_link': 'https://open.spotify.com/artist/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'artist_link': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '4GJ6xDCF5jaUqD6avOuQT6',
# ...

# %%
# Songs Data

songs_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_link = row['track']['external_urls']['spotify']
    song_name = row['track']['name']
    song_popularity = row['track']['popularity']
    song_track_no = row['track']['track_number']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    songs = {'song_id':song_id,'song_link':song_link,'song_name':song_name,'song_popularity':song_popularity,
             'song_track_no':song_track_no, 'song_added':song_added, 'album_id':album_id, 'artist_id':artist_id}
    songs_list.append(songs)
songs_list
# Out:
# [{'song_id': '3qQbCzHBycnDpGskqOWY0E',
#   'song_link': 'https://open.spotify.com/track/3qQbCzHBycnDpGskqOWY0E',
#   'song_name': 'Ella Baila Sola',
#   'song_popularity': 90,
#   'song_track_no': 6,
#   'song_added': '2023-05-19T15:28:49Z',
#   'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'artist_id': '0XeEobZplHxzM9QzFQWLiR'},
#  {'song_id': '6pD0ufEQq0xdHSsRbg9LBK',
#   'song_link': 'https://open.spotify.com/track/6pD0ufEQq0xdHSsRbg9LBK',
#   'song_name': 'un x100to',
#   'song_popularity': 100,
#   'song_track_no': 1,
#   'song_added': '2023-05-19T15:28:49Z',
#   'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'artist_id': '6XkjpgcEsYab502Vr1bBeW'},
#  {'song_id': '2UW7JaomAMuX9pZrjVpHAU',
#   'song_link': 'https://open.spotify.com/track/2UW7JaomAMuX9pZrjVpHAU',
#   'song_name': 'La Bebe - Remix',
#   'song_popularity': 99,
#   'song_track_no': 1,
#   'song_added': '2023-05-19T15:28:49Z',
#   'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'artist_id': '1NNRWkhwmcXRimFYSBpB1y'},
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 1  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 2  6XkjpgcEsYab502Vr1bBeW  Grupo Frontera
# 3  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 4  1NNRWkhwmcXRimFYSBpB1y       Yng Lvcas
#
#                                          artist_link
# 0  https://open.spotify.com/artist/0XeEobZplHxzM9...
# 1  https://open.spotify.com/artist/12GqGscKJx3aE4...
# 2  https://open.spotify.com/artist/6XkjpgcEsYab50...
# 3  https://open.spotify.com/artist/4q3ewBCX7sLwd2...
# 4  https://open.spotify.com/artist/1NNRWkhwmcXRim...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    75 non-null     object
#  1   artist_name  75 non-null     object
#  2   artist_link  75 non-null     object
# dtypes: object(3)
# memory usage: 1.9+ KB

# %%
songs_df = pd.DataFrame.from_dict(songs_list)
songs_df.head()
# Out:
#                   song_id                                          song_link  \
# 0  3qQbCzHBycnDpGskqOWY0E  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1  6pD0ufEQq0xdHSsRbg9LBK  https://open.spotify.com/track/6pD0ufEQq0xdHSs...
# 2  2UW7JaomAMuX9pZrjVpHAU  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 3  7FbrGaHYVDmfr7KoLIZnQ7  https://open.spotify.com/track/7FbrGaHYVDmfr7K...
# 4  4DHcnVTT87F0zZhRPYmZ3B  https://open.spotify.com/track/4DHcnVTT87F0zZh...
#
#            song_name  song_popularity  song_track_no            song_added  \
# 0    Ella Baila Sola               90              6  2023-05-19T15:28:49Z
# 1          un x100to              100              1  2023-05-19T15:28:49Z
# 2    La Bebe - Remix               99              1  2023-05-19T15:28:49Z
# 3  Cupid - Twin Ver.               98              2  2023-05-19T15:28:49Z
# 4            Flowers               91              1  2023-05-19T15:28:49Z
#
#                  album_id               artist_id
# ...

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_link        50 non-null     object
#  2   song_name        50 non-null     object
#  3   song_popularity  50 non-null     int64
#  4   song_track_no    50 non-null     int64
#  5   song_added       50 non-null     object
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id                                         album_link  \
# 0  5aDEezKnOqyQo0qvTFhpkM  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 1  7aGzSSUD8S6IhPCsZSiuMT  https://open.spotify.com/album/7aGzSSUD8S6IhPC...
# 2  6aBVGuOUEuX18rHxyDWbti  https://open.spotify.com/album/6aBVGuOUEuX18rH...
# 3  5letLUZIFsQikJYShfGNs4  https://open.spotify.com/album/5letLUZIFsQikJY...
# 4  0HiZ8fNXwJOQcrf5iflrdz  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
#
#                 album_name    rel_date  total_tracks
# 0                DESVELADO  2023-04-28            16
# 1                un x100to  2023-04-17             1
# 2          La Bebe (Remix)  2023-03-17             2
# 3     The Beginning: Cupid  2023-02-24             3
# 4  Endless Summer Vacation  2023-03-10            13

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_link    50 non-null     object
#  2   album_name    50 non-null     object
#  3   rel_date      50 non-null     object
#  4   total_tracks  50 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df['rel_date'] = pd.to_datetime(album_df['rel_date'])

# %%
songs_df['song_added'] = pd.to_datetime(songs_df['song_added'])
songs_df.head()
# Out:
#                   song_id                                          song_link  \
# 0  3qQbCzHBycnDpGskqOWY0E  https://open.spotify.com/track/3qQbCzHBycnDpGs...
# 1  6pD0ufEQq0xdHSsRbg9LBK  https://open.spotify.com/track/6pD0ufEQq0xdHSs...
# 2  2UW7JaomAMuX9pZrjVpHAU  https://open.spotify.com/track/2UW7JaomAMuX9pZ...
# 3  7FbrGaHYVDmfr7KoLIZnQ7  https://open.spotify.com/track/7FbrGaHYVDmfr7K...
# 4  4DHcnVTT87F0zZhRPYmZ3B  https://open.spotify.com/track/4DHcnVTT87F0zZh...
#
#            song_name  song_popularity  song_track_no  \
# 0    Ella Baila Sola               90              6
# 1          un x100to              100              1
# 2    La Bebe - Remix               99              1
# 3  Cupid - Twin Ver.               98              2
# 4            Flowers               91              1
#
#                  song_added                album_id               artist_id
# 0 2023-05-19 15:28:49+00:00  5aDEezKnOqyQo0qvTFhpkM  0XeEobZplHxzM9QzFQWLiR
# ...

# %%
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   song_id          50 non-null     object
#  1   song_link        50 non-null     object
#  2   song_name        50 non-null     object
#  3   song_popularity  50 non-null     int64
#  4   song_track_no    50 non-null     int64
#  5   song_added       50 non-null     datetime64[ns, UTC]
#  6   album_id         50 non-null     object
#  7   artist_id        50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
